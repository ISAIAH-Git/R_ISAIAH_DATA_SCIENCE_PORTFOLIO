# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
page=requests.get('https://www.nobroker.in/property/sale/hyderabad/Banjara%20Hills/?searchParam=W3sibGF0IjoxNy40MTY4ODksImxvbiI6NzguNDM4NjcsInBsYWNlSWQiOiJDaElKcFREQzV5aVh5enNSb01yMzlWS1g5UXMiLCJwbGFjZU5hbWUiOiJCYW5qYXJhIEhpbGxzIn1d&price=0,100000000000000&lat_lng=17.416889,78.43867&latitude=17.416889&longitude=78.43867&exclusiveProperty=false&propType=AP,IH,GC,SB&type=BHK4PLUS&orderBy=nbRank,desc&radius=2&traffic=true&travelTime=30&propertyType=sale')

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <meta content="794951570520699" property="fb:pages"/>\n  <link href="https://www.nobroker.in/property/sale/hyderabad/Banjara Hills?nbPlace=" rel="canonical"/>\n  <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>\n  <link href="//fonts.googleapis.com/css?family=Source+Sans+Pro:200,300,400,600,700,900,200italic,300italic,400italic,600italic,700italic,900italic" rel="stylesheet" type="text/css"/>\n  <meta charset="utf-8"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <meta content="4+ BHK flats for sale in Banjara Hills, 4+ BHK apartments for sale in Banjara Hills, houses for sale in Banjara Hills" name="keywords"/>\n  <meta content="4+ BHK Apartments, Flats for Sale in Banjara Hills, Hyderabad | 4+ BHK Flats in Banjara Hills - NoBroker" property="og:title"/>\n  <meta content="Searching 4+ BHK Flats, Apartments for SALE in Banjara Hills, Hyderabad ? Get verified list of flats for sale WITHOUT BROKER and SAVE YOUR MONEY" property="og:description"/>\n  <meta content="https://www.nobroker.in/property/sale/hyderabad/Banjara Hills?nbPlace=" property="og:url"/>\n  <meta content="https://images.nobroker.in/images/8a9f828b75e8f9c00175e94a4b2d1684/null" property="og:image"/>\n  <meta content="360" property="og:image:height"/>\n  <meta content="540" property="og:image:width"/>\n  <meta content="289265624583131" property="fb:app_id">\n   <meta content="NoBroker" property="og:site_name"/>\n   <meta content="product" property="og:type"/>\n   <meta content="notranslate" name="google"/>\n   <meta content="hLy7ta67b2CS6LQFWI3SrB22XIuKUHlAHGEi-0W0ngI" name="google-site-verification">\n    <meta content="81EEED055BF8993A564A4B24AF189813" name="msvalidate.01">\n     <meta content="e5c74d79345e920627558faecd28fae5" name="p:domain_verify">\n      <meta content="239876242888-mbq11kse03n78gs2o5549clvlcv3ls24.apps.googleusercontent.com" name="google-signin-client_id"/>\n      <title>\n       4+ BHK Apartments, Flats for Sale in Banjara Hills, Hyderabad | 4+ BHK Flats in Banjara Hills - NoBroker\n      </title>\n      <meta content="Searching 4+ BHK Flats, Apartments for SALE in Banjara Hills, Hyderabad ? Get verified list of flats for sale WITHOUT BROKER and SAVE YOUR MONEY" name="description"/>\n      <meta content="width=device-width,initial-scale=1,user-scalable=no" name="viewport">\n       <meta content="IE=edge,chrome=1" name="X-UA-Compatible">\n        <link href="/manifest.json" rel="manifest"/>\n        <script src="//assets.nobroker.in/static/lib/jquery.min.js" type="text/javascript">\n        </script>\n        <link href="//assets.nobroker.in/static/css/bootstrap.min.css" rel="stylesheet">\n         <link href="//assets.nobroker.in/static/css/jquery.datetimepicker.min1606275209954.css" rel="stylesheet">\n          <link href="//assets.nobroker.in/static/css/bootstrap-social.min.css" rel="stylesheet">\n           <link href="//assets.nobroker.in/static/css/datepicker.min1606275209954.css" rel="stylesheet"/>\n           <link href="//assets.nobroker.in/static/css/slider.min1606275209954.css" rel="stylesheet"/>\n           <link href="//assets.nobroker.in/static/css/bootstrap-select.min1606275209954.css" rel="stylesheet"/>\n           <link href="//assets.nobroker.in/static/css/fotorama.min1606275209954.css" rel="stylesheet"/>\n           <link href="//assets.nobroker.in/static/css/prettyCheckable.min1606275209954.css" rel="stylesheet"/>\n           <link href="//assets.nobroker.in/static/css/imgCarousel/nobrokerSlider.min1606275209954.css" rel="stylesheet"/>\n           <script defer="" src="//assets.nobroker.in/static/lib/vendor/progress.min.js" type="text/javascript">\n           </script>\n           <script src="//assets.nobroker.in/static/lib/universal/nbCache.min1606275209954.js" type="text/javascript">\n           </script>\n           <link href="//cdnjs.cloudflare.com/ajax/libs/fancybox/2.1.5/jquery.fancybox.min.css" rel="styles ...

# %%
names=soup.find_all('h2')
names
# Out:
# [<h2 class="modal-title">Owner Contact Details</h2>,
#  <h2 class="modal-title"><img src="//images.nobroker.in/static/img/builder/Success.png"/> Owner Contact Details</h2>,
#  <h2>Enjoy!!</h2>,
#  <h2>
#  4+ BHK For Sale in Gar Amali, Banjara Hills
#  <i class="icon icon-external-link"></i>
#  </h2>,
#  <h2>
#  4+ BHK For Sale in Masab Tank
#  <i class="icon icon-external-link"></i>
#  </h2>,
#  <h2>
#  4+ BHK For Sale in Jubilee Hills
#  <i class="icon icon-external-link"></i>
#  </h2>,
#  <h2>
#  4+ BHK For Sale in Banjara Hills
#  <i class="icon icon-external-link"></i>
#  </h2>,
#  <h2>
#  4+ BHK For Sale in Banjara Hills
#  <i class="icon icon-external-link"></i>
#  </h2>,
#  <h2>
#  4+ BHK For Sale in standalone bulding, Banjara Hills
#  <i class="icon icon-external-link"></i>
#  </h2>,
#  <h2>
#  4+ BHK For Sale in Banjara hills
#  <i class="icon icon-external-link"></i>
#  </h2>,
#  <h2>
#  4+ BHK For Sale in Banjara Hills
#  <i class="icon icon-external-link"></i>
#  </h2>,
#  <h2>
#  4+ BHK For Sale in Banjara Hills
#  <i class="icon icon-external-link"></i>
#  </h2>,
#  <h2>
#  4+ BHK For Sale in Banjara Hills
#  <i class="icon icon-external-link"></i>
#  </h2>]

# %%
len(names)
# Out:
# 13

# %%
names[3].text
# Out:
# '\n4+ BHK For Sale in Gar Amali, Banjara Hills\n\n'

# %%
names[12].text.strip('\n')
# Out:
# '4+ BHK For Sale in Banjara Hills'

# %%
name=[]
for i in range(3,13):
    name.append(names[i].text.strip('\n'))

# %%
name
# Out:
# ['4+ BHK For Sale in Gar Amali, Banjara Hills',
#  '4+ BHK For Sale in Masab Tank',
#  '4+ BHK For Sale in Jubilee Hills',
#  '4+ BHK For Sale in Banjara Hills',
#  '4+ BHK For Sale in Banjara Hills',
#  '4+ BHK For Sale in standalone bulding, Banjara Hills',
#  '4+ BHK For Sale in Banjara hills',
#  '4+ BHK For Sale in Banjara Hills',
#  '4+ BHK For Sale in Banjara Hills',
#  '4+ BHK For Sale in Banjara Hills']

# %%
ad=soup.find_all('h5')

# %%
ad[81]
# Out:
# <h5>
# Standalone Building, Road No 10,behind Namasthe Te ...
# <span class="" data-toggle="modal" href="#listMap" onclick="intiateMapViewInPopup('17.416','78.434');" role="button" title="view location on map"><img class="explore-nearby-img" src="https://images.nobroker.in/static/img/list-location-icon.png"/></span>
# <a class="explore-nearby" href="https://www.nobroker.in/property/buy/4%2b-bhk-apartment-for-sale-in-banjara-hills--hyderabad/ff8081816ebbbc86016ebbea5df435c4/detail?ga_source=buy#explore-nearby" onclick="setSeenPropertyMarker('ff8081816ebbbc86016ebbea5df435c4')" target="_blank" title="4+ BHK For Sale in Banjara Hills ">
# Explore Nearby
# </a>
# </h5>

# %%
ad[8].text.strip('\n')[:54]
# Out:
# '414, 8-2-414, Road Number 4, Banjara Hills, Hydera ...'

# %%
ad[16].text.strip('\n')[:52]
# Out:
# 'Independent House, Road No.1, Banjara Hills Near ...'

# %%
address=[]
for i in range(8,64,8):
    k=ad[i].text.strip('\n').find('\n')
    address.append(ad[i].text.strip('\n')[:k])

# %%
address
# Out:
# ['414, 8-2-414, Road Number 4, Banjara Hills, Hydera ...',
#  'Independent House, Road No.1, Banjara Hills Near ...',
#  'Independent House, Ias Officers Quaters, Nandi Nag ...',
#  'Independent House, Prem Naga, Khairtabad, Banjara ...',
#  'Independent House, Road No 3, Near Banjara Hills P ...',
#  'Road No. 10, Ias Officers Quaters, Near Basavatara ...',
#  'Independent House, Nandi Nagar, Near Basavatarakam ...']

# %%
for i in range(65,82,8):
    k=ad[i].text.strip('\n').find('\n')
    address.append(ad[i].text.strip('\n')[:k])

# %%
address
# Out:
# ['414, 8-2-414, Road Number 4, Banjara Hills, Hydera ...',
#  'Independent House, Road No.1, Banjara Hills Near ...',
#  'Independent House, Ias Officers Quaters, Nandi Nag ...',
#  'Independent House, Prem Naga, Khairtabad, Banjara ...',
#  'Independent House, Road No 3, Near Banjara Hills P ...',
#  'Road No. 10, Ias Officers Quaters, Near Basavatara ...',
#  'Independent House, Nandi Nagar, Near Basavatarakam ...',
#  'Standalone Building, Road No 10, Near Masjid-e-rah ...',
#  'Independent House, Road Number 3,near Banjara Hill ...',
#  'Standalone Building, Road No 10, Near Masjid-e-rah ...',
#  'Independent House, Road Number 3,near Banjara Hill ...',
#  'Standalone Building, Road No 10,behind Namasthe Te ...']

# %%
len(address)
# Out:
# 12

# %%
import numpy as np
data=pd.DataFrame({'names':name,'address':address[:10]})
data
# Out:
#                                                names  \
# 0        4+ BHK For Sale in Gar Amali, Banjara Hills
# 1                      4+ BHK For Sale in Masab Tank
# 2                   4+ BHK For Sale in Jubilee Hills
# 3                   4+ BHK For Sale in Banjara Hills
# 4                   4+ BHK For Sale in Banjara Hills
# 5  4+ BHK For Sale in standalone bulding, Banjara...
# 6                   4+ BHK For Sale in Banjara hills
# 7                   4+ BHK For Sale in Banjara Hills
# 8                   4+ BHK For Sale in Banjara Hills
# 9                   4+ BHK For Sale in Banjara Hills
#
#                                              address
# 0  414, 8-2-414, Road Number 4, Banjara Hills, Hy...
# 1  Independent House, Road No.1, Banjara Hills Ne...
# 2  Independent House, Ias Officers Quaters, Nandi...
# 3  Independent House, Prem Naga, Khairtabad, Banj...
# 4  Independent House, Road No 3, Near Banjara Hil...
# 5  Road No. 10, Ias Officers Quaters, Near Basava...
# 6  Independent House, Nandi Nagar, Near Basavatar...
# 7  Standalone Building, Road No 10, Near Masjid-e...
# 8  Independent House, Road Number 3,near Banjara ...
# 9  Standalone Building, Road No 10, Near Masjid-e...

# %%
area=soup.find_all('div',class_="col-sm-4 solid-border-right")

# %%
k=area[0].text.strip('\n').find('\n')
area[0].text.strip('\n')[:k]
# Out:
# '3,545 sqft'

# %%
area[1].text
# Out:
# '\n\n\n 3.16 Lacs/Month\n\n\n\nEstimated EMI\n\n'

# %%
area[2].text
# Out:
# '\n\n\n3,240 sqft\n\n\n\nBuiltup\n\n'

# %%
area[3].text
# Out:
# '\n\n\n 3.51 Lacs/Month\n\n\n\nEstimated EMI\n\n'

# %%
area[19].text
# Out:
# '\n\n\n 6.32 Lacs/Month\n\n\n\nEstimated EMI\n\n'

# %%
len(area)
# Out:
# 20

# %%
area[0]
# Out:
# <div class="col-sm-4 solid-border-right" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue" style="border-right:1px solid #EBEBEB;">
# <h3>
# <meta content="property size" itemprop="name"/>
# <span>3,545</span><span itemprop="unitText"> sqft</span>
# <meta content="3545" itemprop="value"/>
# </h3>
# <h5>
# Builtup
# </h5>
# </div>

# %%
areas=[]
for i in range(0,20,2):
    k=area[i].text.strip('\n').find('\n')
    areas.append(area[i].text.strip('\n')[:k])

# %%
data['area']=areas

# %%
EMI=[]
for i in range(1,20,2):
    j=area[i].text.strip('\n').find('\n')
    EMI.append(area[i].text.strip('\n')[:j])

# %%
data['EMI']=EMI

# %%
cost=soup.find_all('h3')

# %%
cost[15].text.strip('\n')
# Out:
# ' 4.5 Crores'

# %%
totalcost=[]
for i in range(15,43,3):
    totalcost.append(cost[i].text.strip('\n'))

# %%
totalcost
# Out:
# [' 4.5 Crores',
#  ' 5 Crores',
#  ' 3.5 Crores',
#  ' 3 Crores',
#  ' 8 Crores',
#  ' 19 Crores',
#  ' 90 Lacs',
#  ' 10 Crores',
#  ' 6 Crores',
#  ' 9 Crores']

# %%
data['cost']=totalcost

# %%
data
# Out:
#                                                names  \
# 0        4+ BHK For Sale in Gar Amali, Banjara Hills
# 1                      4+ BHK For Sale in Masab Tank
# 2                   4+ BHK For Sale in Jubilee Hills
# 3                   4+ BHK For Sale in Banjara Hills
# 4                   4+ BHK For Sale in Banjara Hills
# 5  4+ BHK For Sale in standalone bulding, Banjara...
# 6                   4+ BHK For Sale in Banjara hills
# 7                   4+ BHK For Sale in Banjara Hills
# 8                   4+ BHK For Sale in Banjara Hills
# 9                   4+ BHK For Sale in Banjara Hills
#
#                                              address                EMI  \
# 0  414, 8-2-414, Road Number 4, Banjara Hills, Hy...    3.16 Lacs/Month
# 1  Independent House, Road No.1, Banjara Hills Ne...    3.51 Lacs/Month
# 2  Independent House, Ias Officers Quaters, Nandi...    2.46 Lacs/Month
# 3  Independent House, Prem Naga, Khairtabad, Banj...    2.11 Lacs/Month
# 4  Independent House, Road No 3, Near Banjara Hil...    5.61 Lacs/Month
# 5  Road No. 10, Ias Officers Quaters, Near Basava...   13.34 Lacs/Month
# 6  Independent House, Nandi Nagar, Near Basavatar...       63,168/Month
# 7  Standalone Building, Road No 10, Near Masjid-e...    7.02 Lacs/Month
# 8  Independent House, Road Number 3,near Banjara ...    4.21 Lacs/Month
# 9  Standalone Building, Road No 10, Near Masjid-e...    6.32 Lacs/Month
#
#          area         cost
# 0  3,545 sqft   4.5 Crores
# 1  3,240 sqft     5 Crores
# 2  5,000 sqft   3.5 Crores
# 3  6,480 sqft     3 Crores
# 4  2,105 sqft     8 Crores
# 5  6,000 sqft    19 Crores
# 6  2,160 sqft      90 Lacs
# 7  6,500 sqft    10 Crores
# 8  3,105 sqft     6 Crores
# 9  6,000 sqft     9 Crores
